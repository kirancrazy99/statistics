# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sample=np.random.randint(1,20,size=10)
sample
# Out:
# array([ 1,  7,  2,  6,  9, 16,  4,  4, 17, 19])

# %%
plt.hist(sample)
# Out:
# (array([2., 2., 1., 1., 1., 0., 0., 0., 2., 1.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]),
#  <a list of 10 Patch objects>)

# %%
data=[22,25,22,27,24,23,26,24,22,24,26]
plt.hist(data,color='b',bins=11)
plt.show()

# %%
data=[86,80,25,77,73,76,100,90,69,93,90,83,70,73,73,70,90,83,71,95,40,58,68,69,100,78,87,97,92,74]
stemgraphic.stem_graphic(data)
# Out:
# (<Figure size 540x216 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x24c23adfc88>)

# %%
data=[100,200,223,332,442,553]
stemgraphic.stem_graphic(data,scale=100)
# Out:
# (<Figure size 540x144 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x24c25838b88>)

# %%
data=np.array([86,80,25,77,73,76,100,90,69,93,90,83,70,73,73,70,90,83,71,95,40,58,68,69,100,78,87,97,92,74])
fig=plt.figure()
ax=fig.add_subplot(111)
ax.hist(data, weights=np.zeros_like(data) + 1. / data.size)
ax.set_xlabel('Bins', size=20)
ax.set_ylabel('Frequency', size=20)
ax.legend
plt.show()

# %%
data=np.array([86,80,25,77,73,76,100,90,69,93,90,83,70,73,73,70,90,83,71,95,40,58,68,69,100,78,87,97,92,74])
fig=plt.figure()
ax=fig.add_subplot(111)
ax.hist(data)
ax.set_xlabel('Bins', size=20)
ax.set_ylabel('Frequency', size=20)
ax.legend
plt.show()

# %%
data=[69,92,68,77,80,70,85,88,85,96]
plt.hist(data,color='r',stacked=True,fill=True)
plt.xlabel('Data')
plt.ylabel('Frequency')
plt.xlim(50,100)
plt.show()

# %%
data=[8.5,6.5,9.6,8.0,8.2,8.2,8.5,7.7,7.0,7.6,8.8,2.9,7.0,1.5,8.5,9.2,4.9,9.3]
plt.hist(data,histtype='barstacked')
plt.show()

# %%
data=np.array([-1,-1,-1,0,0,0,0,1,1,2])
plt.hist(data,range=([-1,2]))
plt.show()

# %%
o='O'*136
a='A'*120
b='B'*32
ab='AB'*12
o_data=[i for i in o]
a_data=[i for i in a]
b_data=[i for i in b]
ab_data=[i for i in ab]
data=o_data+a_data+b_data+ab_data

# %%
plt.hist(data)
plt.show()
